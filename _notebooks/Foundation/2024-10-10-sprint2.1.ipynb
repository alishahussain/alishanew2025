# %% [markdown]
# ---
# layout: post
# title: Sprint 2 Presentation
# categories: [Collaboration]
# courses: {csa: {week: 7} }
# type: collab
# comments: true
# ---

# %% [markdown]
# - Blog - in association with Units and Teaching, something that shows how you will be prepared for CB and PBL (ie organized accomplishments)
# - Memory - something that will help Mr M or others recall your individual presentation and contribution (ie a highlight)
# - Relevancy - something impactful you learned from another lesson, note source, and try to use relevancy checklist in language (ie a learning)
# - Beyond Perfunctory - something that shows me that this Sprint on Units is distinctly yours (ie personal growth or accomplishment)

# %% [markdown]
# # [Sprint 2](https://alishahussain.github.io/alishanew2025/collaboration/2024/10/08/sprint2_IPYNB_2_.html)

# %% [markdown]
# <head>
#     <title>AP CSA Blog</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             margin: 0;
#             padding: 20px;
#             background-color: #f7ede2;
#             color: #333;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#             font-size: 2.5em;
#             color: #457b9d;
#         }
#         h2 {
#             cursor: pointer;
#             margin: 20px 0;
#             padding: 15px;
#             background-color: #a8dadc;
#             color: #ffffff;
#             border-radius: 10px;
#             transition: transform 0.3s ease, background-color 0.3s ease;
#             position: relative;
#         }
#         h2:hover {
#             transform: translateY(-5px);
#             background-color: #f4a261;
#         }
#         h2:hover::after {
#             content: attr(data-hover);
#             position: absolute;
#             left: 100%;
#             top: 50%;
#             transform: translateY(-50%);
#             background-color: #fefae0;
#             color: #005f73;
#             padding: 10px;
#             border-radius: 10px;
#             white-space: nowrap;
#             margin-left: 15px;
#             font-size: 0.9em;
#         }
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0;
#             top: 0;
#             width: 100%;
#             height: 100%;
#             background-color: rgba(0, 0, 0, 0.6);
#         }
#         .modal-content {
#             background-color: #fefae0;
#             margin: 10% auto;
#             padding: 20px;
#             width: 90%;
#             max-width: 700px;
#             border-radius: 15px;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.2);
#         }
#         .close {
#             color: #e63946;
#             font-size: 28px;
#             font-weight: bold;
#             float: right;
#         }
#         .close:hover,
#         .close:focus {
#             color: #d62828;
#             text-decoration: none;
#             cursor: pointer;
#         }
#         .modal-header {
#             font-size: 2em;
#             color: #457b9d;
#             text-align: center;
#             margin-bottom: 20px;
#         }
#         .modal-body {
#             background-color: #ffbe0b;
#             font-size: 1.2em;
#             line-height: 1.8;
#             color: #264653;
#         }
#         .bullet-point-section ul {
#             list-style-type: square;
#             margin-left: 20px;
#         }
#         .blog-link {
#             display: block;
#             text-align: center;
#             margin-top: 20px;
#             font-size: 1.2em;
#             background-color: #457b9d;
#             color: #ffffff;
#             padding: 10px;
#             border-radius: 10px;
#             text-decoration: none;
#         }
#         .blog-link:hover {
#             background-color: #1d3557;
#         }
#     </style>
# </head>
# <body>
#     <h1>Blog - Team Teaches</h1>
#     <!-- Unit 1 -->
#     <h2 onclick="openModal('unit1Modal')">Unit 1: Primitive Types</h2>
#     <div id="unit1Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit1Modal')">&times;</span>
#             <div class="modal-header">Unit 1: Primitive Types</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>Integer division cuts off decimals (e.g., 5 / 2 = 2). Use double for division with decimals.</li>
#                         <li>Type casting changes types (e.g., (int) 5.7 becomes 5), but can lose precision.</li>
#                         <li>Overflow happens when a number is too big for its type (e.g., int max is about 2 billion).</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit1/intro" class="blog-link">Go to Unit 1 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 2 -->
#     <h2 onclick="openModal('unit2Modal')">Unit 2: Using Objects</h2>
#     <div id="unit2Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit2Modal')">&times;</span>
#             <div class="modal-header">Unit 2: Using Objects</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>Strings don’t change once created—methods like substring() return a new String.</li>
#                         <li>Use equals() to compare strings (not ==).</li>
#                         <li>Wrapper classes (like Integer, Double) are used to work with primitive types as objects.</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit2/period3/home/" class="blog-link">Go to Unit 2 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 3 -->
#     <h2 onclick="openModal('unit3Modal')">Unit 3: Boolean Expressions and if Statements</h2>
#     <div id="unit3Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit3Modal')">&times;</span>
#             <div class="modal-header">Unit 3: Boolean Expressions and if Statements</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>`&&` (AND) and `||` (OR) stop checking conditions as soon as the result is decided.</li>
#                         <li>Use == carefully; for objects like Strings, use equals() instead.</li>
#                         <li>else if ensures only one condition runs, even if more than one is true.</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit3-p1/intro/" class="blog-link">Go to Unit 3 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 4 -->
#     <h2 onclick="openModal('unit4Modal')">Unit 4: Iteration</h2>
#     <div id="unit4Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit4Modal')">&times;</span>
#             <div class="modal-header">Unit 4: Iteration</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>Watch for off-by-one errors in loops, especially with arrays (start at 0).</li>
#                         <li>`for-each` loops are great for going through arrays when you don’t need to change the items.</li>
#                         <li>Be careful with loop conditions to avoid infinite loops.</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit4-p1/" class="blog-link">Go to Unit 4 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 5 -->
#     <h2 onclick="openModal('unit5Modal')">Unit 5: Writing Classes</h2>
#     <div id="unit5Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit5Modal')">&times;</span>
#             <div class="modal-header">Unit 5: Writing Classes</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>Keep fields private and use getters/setters to access them.</li>
#                         <li>Use constructors to set up objects with initial values.</li>
#                         <li>Avoid confusing overloaded methods (same name, different parameters).</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/period1/unit5/intro" class="blog-link">Go to Unit 5 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 6 -->
#     <h2 onclick="openModal('unit6Modal')">Unit 6: Array</h2>
#     <div id="unit6Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit6Modal')">&times;</span>
#             <div class="modal-header">Unit 6: Array</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>Arrays can’t change size once created. Use ArrayList if you need resizing.</li>
#                         <li>Array indices start at 0. Going outside the bounds throws an error.</li>
#                         <li>Arrays store object references, not the actual objects.</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit6-p1/" class="blog-link">Go to Unit 6 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 7 -->
#     <h2 onclick="openModal('unit7Modal')">Unit 7: ArrayList</h2>
#     <div id="unit7Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit7Modal')">&times;</span>
#             <div class="modal-header">Unit 7: ArrayList</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>ArrayLists grow or shrink as needed, but you must use add() and remove().</li>
#                         <li>Always declare types (e.g., ArrayList&lt;Integer&gt;) to avoid errors.</li>
#                         <li>Use get() to access items and size() to find the number of elements.</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit7-p1/" class="blog-link">Go to Unit 7 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 8 -->
#     <h2 onclick="openModal('unit8Modal')">Unit 8: 2D Arrays</h2>
#     <div id="unit8Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit8Modal')">&times;</span>
#             <div class="modal-header">Unit 8: 2D Arrays</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>2D arrays are arrays of arrays. Access with two indices: array[row][col].</li>
#                         <li>Use nested loops to go through 2D arrays (outer loop for rows, inner for columns).</li>
#                         <li>Be careful with indexes when working with diagonals or specific areas.</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit8-p1/" class="blog-link">Go to Unit 8 Blog</a>
#             </div>
#         </div>
#     </div>
#     <!-- Unit 9 -->
#     <h2 onclick="openModal('unit9Modal')">Unit 9: Inheritance</h2>
#     <div id="unit9Modal" class="modal">
#         <div class="modal-content">
#             <span class="close" onclick="closeModal('unit9Modal')">&times;</span>
#             <div class="modal-header">Unit 9: Inheritance</div>
#             <div class="modal-body">
#                 <div class="bullet-point-section">
#                     <h3>Main Concepts:</h3>
#                     <ul>
#                         <li>`super()` calls the superclass constructor and must be the first line in the subclass constructor.</li>
#                         <li>Overriding methods means replacing a superclass method in the subclass.</li>
#                         <li>Polymorphism lets a superclass variable hold a subclass object, but it can only call overridden methods unless cast.</li>
#                     </ul>
#                 </div>
#                 <a href="https://alishahussain.github.io/alishanew2025/csa/unit9-p1/" class="blog-link">Go to Unit 9 Blog</a>
#             </div>
#         </div>
#     </div>
#     <script>
#         function openModal(modalId) {
#             document.getElementById(modalId).style.display = "block";
#         }
#         function closeModal(modalId) {
#             document.getElementById(modalId).style.display = "none";
#         }
#         window.onclick = function(event) {
#             const modals = document.getElementsByClassName("modal");
#             for (let i = 0; i < modals.length; i++) {
#                 if (event.target == modals[i]) {
#                     modals[i].style.display = "none";
#                 }
#             }
#         }
#     </script>
# </body>

# %% [markdown]
# # Memories - Boolean Table
#
# <style>
#     #grid {
#         display: grid;
#         grid-template-columns: repeat(5, 100px);
#         grid-gap: 5px;
#     }
#     .square {
#         width: 100px;
#         height: 100px;
#         background-color: white;
#         border: 2px solid black;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         font-size: 24px;
#         color: black; /* Set text color to black */
#     }
# </style>
#
# <div id="grid"></div>
#
# <script>
#     const gridSize = 5; // Grid size
#
#     // Function to create the grid
#     function createGrid() {
#         const grid = document.getElementById('grid');
#
#         for (let i = 0; i < gridSize; i++) {
#             for (let j = 0; j < gridSize; j++) {
#                 const square = document.createElement('div');
#                 square.className = 'square';
#                 square.textContent = 'false'; // Initial text
#                 square.addEventListener('click', () => toggleSquare(square));
#                 grid.appendChild(square);
#             }
#         }
#     }
#
#     // Function to toggle the square's color and text
#     function toggleSquare(square) {
#         if (square.style.backgroundColor === 'red') {
#             square.style.backgroundColor = 'white'; // Turn off color
#             square.textContent = 'false'; // Change text to false
#         } else {
#             square.style.backgroundColor = 'red'; // Turn on color
#             square.textContent = 'true'; // Change text to true
#         }
#     }
#
#     // Initialize the grid
#     createGrid();
# </script>

# %% [markdown]
# <!-- Unit 5 Favorite Takeaways -->
# <h2 onclick="openModal('u5t')">Relevancy - Unit 5 Favorite Takeaways</h2>
# <div id="u5t" class="modal">
#     <div class="modal-content">
#         <span class="close" onclick="closeModal('u5t')">&times;</span>
#         <div class="modal-header">Unit 5 Favorite Takeaways</div>
#         <div class="modal-body">
#             <div class="bullet-point-section">
#                 <h3>Main Concepts:</h3>
#                 <ul>
#                     <li>The way they explained accessor methods and why they protect instance variables made it super easy to get how important encapsulation is in programming.</li>
#                     <li>Using the Snack class as a real example was cool because it made the concept way more understandable and showed how getters work in actual code.</li>
#                     <li>The teaching was super clear and easy to follow, plus there were always people around to help if you had questions, which made it really chill and stress-free to learn.</li>
#                 </ul>
#             </div>
#             <a href="https://nighthawkcoders.github.io/portfolio_2025/csa/period1/unit5/accessor" class="blog-link">Go to Unit 5 Favorite Part</a>
#         </div>
#     </div>
# </div>

# %% [markdown]
# # [Unit 3.1 Redo](https://alishahussain.github.io/alishanew2025/collaboration/2024/10/10/unit3.1_IPYNB_2_.html)

# %% [markdown]
# # [Unit 3.2 Redo](https://alishahussain.github.io/alishanew2025/collaboration/2024/10/10/unit3.2_IPYNB_2_.html)
